# %% [markdown]
# # Model Construction
# This notebook is used to construct a model that can predict the number of available bike stands at a station (and thereby also the number of available bikes). In the first section the required data (bike dynamimc data & weather dynamic data) is imported and some derived features are added to make the dataframe suitable for machine learning. The second part uses random forests to create a model for each station and python's pickel library to export the model.

# %%
import db_connection as db
import pandas as pd
import datetime as dt

# %% [markdown]
# ## 1. Data Import and Analysis
# We import selected columns of two tables from our database (BikeStationDynamicData & WeatherData). Because we queried Bike Station Dynamic Data every five minutes and Weather only every 30 minutes, we first need to join the two tables in such a way that each entry in the BikeStationDynamicData is paired up with the closest entry in the WeatherData table. This is possible as both tables store a Timestamp (one in seconds, other in milliseconds).
#
# Then we do some conversions (unix timestamp to datetime) and derive some features which we think might be helpful in training the model. As datetime entry is difficult for a machine learning algorith to interpret, we break the datetime into several features.

# %%
# Set up query
my_query = '''
select Number, B.Timestamp, BikeStands, AvailableStands, W.Timestamp*1000 as WeatherTime, Temperature, WindSpeed, Clouds, Rain, Snow, Sunrise*1000 as Sunrise, Sunset*1000 as Sunset
from BikeStationDynamicData as B
Left Outer Join WeatherData as W ON
W.TimeStamp = (select We.Timestamp 
from WeatherData as We
where We.Timestamp*1000 >= B.Timestamp - 8600000 and We.TimeStamp*1000 < B.Timestamp + 8600000
order by ABS(We.Timestamp*1000 - B.Timestamp)
Limit 1);
'''

# Query database
df = pd.read_sql(my_query, con=db.cnx)

# %%
# check if any null entries
df.isna().sum()
# Out:
# Number                  0
# Timestamp               0
# BikeStands              0
# AvailableStands         0
# WeatherTime             0
# Temperature             0
# WindSpeed               0
# Clouds                  0
# Rain               364221
# Snow               366811
# Sunrise                 0
# Sunset                  0
# dtype: int64

# %%
# check if right size
df.shape
# Out:
# (366811, 12)

# %%
# assign to a new df and keep original (query takes ages, don't want to repeat in case we need reset)
new_df = df

# convert unix timestamps (ms) to datetime
new_df.Timestamp =pd.to_datetime(df.Timestamp, unit='ms').dt.tz_localize('UTC').dt.tz_convert("Europe/Dublin")
new_df.WeatherTime =pd.to_datetime(df.WeatherTime, unit='ms').dt.tz_localize('UTC').dt.tz_convert("Europe/Dublin")
new_df.Sunrise =(pd.to_datetime(df.Sunrise, unit='ms')).dt.tz_localize('UTC').dt.tz_convert("Europe/Dublin")
new_df.Sunset =(pd.to_datetime(df.Sunset, unit='ms')).dt.tz_localize('UTC').dt.tz_convert("Europe/Dublin")

# %%
# add weekday and hour:minute columns
new_df["hourOfDay"] = new_df.Timestamp.apply(lambda time: "{0:0>2}:{1:0>2}".format(time.hour, time.minute))
new_df["dayOfWeek"] = new_df.Timestamp.apply(lambda time: time.weekday())
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#                     Sunrise                    Sunset hourOfDay  dayOfWeek
# 0 2018-03-27 07:09:57+01:00 2018-03-27 19:51:46+01:00     09:48          1
# 1 2018-03-27 07:09:54+01:00 2018-03-27 19:51:48+01:00     10:50          1
# 2 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:01          1
# 3 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:09          1
# 4 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:10          1

# %%
# add boolean stating if it is a workday
new_df["workday"] = new_df.dayOfWeek.apply(lambda day: day in range(0, 5))
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#                     Sunrise                    Sunset hourOfDay  dayOfWeek  \
# 0 2018-03-27 07:09:57+01:00 2018-03-27 19:51:46+01:00     09:48          1
# 1 2018-03-27 07:09:54+01:00 2018-03-27 19:51:48+01:00     10:50          1
# 2 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:01          1
# 3 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:09          1
# 4 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:10          1
#
#    workday
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %%
# add boolean stating if it is during rush hours
new_df["rushHour"] = new_df.hourOfDay.apply(lambda time: "07:00" <= time <= "09:00" or "16:00" <= time <= "19:00")
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#                     Sunrise                    Sunset hourOfDay  dayOfWeek  \
# 0 2018-03-27 07:09:57+01:00 2018-03-27 19:51:46+01:00     09:48          1
# 1 2018-03-27 07:09:54+01:00 2018-03-27 19:51:48+01:00     10:50          1
# 2 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:01          1
# 3 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:09          1
# 4 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:10          1
#
#    workday  rushHour
# 0     True     False
# 1     True     False
# 2     True     False
# 3     True     False
# 4     True     False

# %%
# add boolean stating if it lunchtime
new_df["lunchHour"] = new_df.hourOfDay.apply(lambda time: "12:00" <= time <= "14:00")
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#                     Sunrise                    Sunset hourOfDay  dayOfWeek  \
# 0 2018-03-27 07:09:57+01:00 2018-03-27 19:51:46+01:00     09:48          1
# 1 2018-03-27 07:09:54+01:00 2018-03-27 19:51:48+01:00     10:50          1
# 2 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:01          1
# 3 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:09          1
# 4 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:10          1
#
#    workday  rushHour  lunchHour
# 0     True     False      False
# 1     True     False      False
# 2     True     False      False
# 3     True     False      False
# 4     True     False      False

# %%
# add boolean stating if it is workhours
new_df["workHour"] = new_df.hourOfDay.apply(lambda time: "09:00" < time < "12:00" or "14:00" < time < "17:00")
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#                     Sunrise                    Sunset hourOfDay  dayOfWeek  \
# 0 2018-03-27 07:09:57+01:00 2018-03-27 19:51:46+01:00     09:48          1
# 1 2018-03-27 07:09:54+01:00 2018-03-27 19:51:48+01:00     10:50          1
# 2 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:01          1
# 3 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:09          1
# 4 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:10          1
#
#    workday  rushHour  lunchHour  workHour
# 0     True     False      False      True
# 1     True     False      False      True
# 2     True     False      False      True
# 3     True     False      False      True
# 4     True     False      False      True

# %%
# add column containing sunrise/sunset time as hour:minute string
new_df["sunriseHour"] = new_df.Sunrise.apply(lambda time: "{0:0>2}:{1:0>2}".format(time.hour, time.minute))
new_df["sunsetHour"] = new_df.Sunset.apply(lambda time: "{0:0>2}:{1:0>2}".format(time.hour, time.minute))
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#                     Sunrise                    Sunset hourOfDay  dayOfWeek  \
# 0 2018-03-27 07:09:57+01:00 2018-03-27 19:51:46+01:00     09:48          1
# 1 2018-03-27 07:09:54+01:00 2018-03-27 19:51:48+01:00     10:50          1
# 2 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:01          1
# 3 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:09          1
# 4 2018-03-27 07:09:51+01:00 2018-03-27 19:51:50+01:00     11:10          1
#
#    workday  rushHour  lunchHour  workHour sunriseHour sunsetHour
# 0     True     False      False      True       07:09      19:51
# 1     True     False      False      True       07:09      19:51
# 2     True     False      False      True       07:09      19:51
# 3     True     False      False      True       07:09      19:51
# 4     True     False      False      True       07:09      19:51

# %%
# add boolean stating if it has daylight
new_df["daylight"] = new_df.apply(lambda row: row["sunriseHour"] <= row["hourOfDay"] <= row["sunsetHour"], axis=1)
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#     ...                       Sunset hourOfDay dayOfWeek  workday  rushHour  \
# 0   ...    2018-03-27 19:51:46+01:00     09:48         1     True     False
# 1   ...    2018-03-27 19:51:48+01:00     10:50         1     True     False
# 2   ...    2018-03-27 19:51:50+01:00     11:01         1     True     False
# 3   ...    2018-03-27 19:51:50+01:00     11:09         1     True     False
# 4   ...    2018-03-27 19:51:50+01:00     11:10         1     True     False
#
#    lunchHour  workHour  sunriseHour sunsetHour daylight
# 0      False      True        07:09      19:51     True
# 1      False      True        07:09      19:51     True
# 2      False      True        07:09      19:51     True
# 3      False      True        07:09      19:51     True
# 4      False      True        07:09      19:51     True
#
# [5 rows x 21 columns]

# %%
# Create classifier functions that can be used to convert numeric features into classes.
def classify_bikeStands(bikeStandsPerc):
    availability = "LOL"
    if bikeStandsPerc <= 0.33:
        availability = "little"
    elif bikeStandsPerc <= 0.66:
        availability = "moderate"
    else:
        availability = "abundant"
    return availability

def classify_temp(temp):
    temp_class = None
    if temp <= 278.15:   #cold
        temp_class = 0 
    elif temp <= 283.15: #tolerable
        temp_class = 1
    elif temp <= 288.15: #moderate
        temp_class = 2
    elif temp <= 293.15: #warm
        temp_class = 3
    else:                #hot
        temp_class = 4
    return temp_class

def classify_daytime(time, sunrise, sunset):
    daytime_class = None
    if sunrise <= time <= sunset:
        if time < "12:00":
            daytime_class = "morning"
        elif time < "17:00":
            daytime_class = "afternoon"
        else:
            daytime_class = "evening"
    else:
        if sunset < time < "24:00":
            daytime_class = "darkEvening"
        else:
            daytime_class = "night"
    return daytime_class
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#     ...                       Sunset hourOfDay dayOfWeek  workday  rushHour  \
# 0   ...    2018-03-27 19:51:46+01:00     09:48         1     True     False
# 1   ...    2018-03-27 19:51:48+01:00     10:50         1     True     False
# 2   ...    2018-03-27 19:51:50+01:00     11:01         1     True     False
# 3   ...    2018-03-27 19:51:50+01:00     11:09         1     True     False
# 4   ...    2018-03-27 19:51:50+01:00     11:10         1     True     False
#
#    lunchHour  workHour  sunriseHour sunsetHour daylight
# 0      False      True        07:09      19:51     True
# 1      False      True        07:09      19:51     True
# 2      False      True        07:09      19:51     True
# 3      False      True        07:09      19:51     True
# 4      False      True        07:09      19:51     True
#
# [5 rows x 21 columns]

# %%
# Convert some numeric features into categorical ones
new_df["bikeStandsPerc"]= new_df.apply(lambda row: classify_bikeStands(row.AvailableStands/row.BikeStands), axis=1)
new_df["tempClass"]= new_df.Temperature.apply(lambda temp: classify_temp(temp))
new_df["dayTime"]= new_df.apply(lambda row: classify_daytime(row.hourOfDay, row.sunriseHour, row.sunsetHour), axis=1)

# %% [markdown]
# ## 2. Model Training

# %%
# Import required packages for model training
import numpy as np
import matplotlib.pyplot as plt
import pickle
from patsy import dmatrices
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# Out:
# c:\users\roman\anaconda3\envs\semester_two_env\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# the categoricla daytime column needs to be split into several boolean columns
daytimes = pd.get_dummies(new_df.dayTime, prefix='daytime').iloc[:, 1:]
new_df = pd.concat([new_df, daytimes], axis=1)
daytimes.head()
# Out:
#    daytime_darkEvening  daytime_evening  daytime_morning  daytime_night
# 0                    0                0                1              0
# 1                    0                0                1              0
# 2                    0                0                1              0
# 3                    0                0                1              0
# 4                    0                0                1              0

# %%
new_df.head()
# Out:
#    Number                 Timestamp  BikeStands  AvailableStands  \
# 0       1 2018-03-27 09:48:06+01:00          31               12
# 1       1 2018-03-27 10:50:37+01:00          31                7
# 2       1 2018-03-27 11:01:16+01:00          31                5
# 3       1 2018-03-27 11:09:38+01:00          31                4
# 4       1 2018-03-27 11:10:16+01:00          31                6
#
#                 WeatherTime  Temperature WindSpeed  Clouds  Rain  Snow  \
# 0 2018-03-27 10:00:00+01:00          281       9.3      75   NaN  None
# 1 2018-03-27 10:30:00+01:00          281       9.8      75   NaN  None
# 2 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 3 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
# 4 2018-03-27 11:30:00+01:00          282       8.2      75   NaN  None
#
#        ...      sunriseHour sunsetHour daylight  bikeStandsPerc  tempClass  \
# 0      ...            07:09      19:51     True        moderate          1
# 1      ...            07:09      19:51     True          little          1
# 2      ...            07:09      19:51     True          little          1
# 3      ...            07:09      19:51     True          little          1
# 4      ...            07:09      19:51     True          little          1
#
#    dayTime  daytime_darkEvening  daytime_evening daytime_morning daytime_night
# 0  morning                    0                0               1             0
# 1  morning                    0                0               1             0
# 2  morning                    0                0               1             0
# 3  morning                    0                0               1             0
# 4  morning                    0                0               1             0
#
# [5 rows x 28 columns]

# %%
# see how the model perform by using corss validation
# Commented out as it takes ages to run
'''
for number in new_df.Number.unique():
    sub_df = new_df[new_df.Number==number]
    X = sub_df[["tempClass", "WindSpeed", "Clouds", "workday", "rushHour", "daylight", "lunchHour", "daytime_darkEvening", "daytime_evening", "daytime_morning", "daytime_night"]]
    y = sub_df["bikeStandsPerc"]
    
    rfc = RandomForestClassifier(n_estimators=100, max_features='auto', oob_score=True, random_state=1)
    scores = cross_val_score(rfc, X, y, scoring='accuracy', cv=5)
    print("Model for Station {} has Accuracy: {}".format(number, scores.mean()))
'''
# Out:
# Model for Station 1 has Accuracy: 0.4675714846271661
# Model for Station 2 has Accuracy: 0.4042083756418215
# Model for Station 3 has Accuracy: 0.6297678467930206
# Model for Station 4 has Accuracy: 0.5983913129236871
# Model for Station 5 has Accuracy: 0.38304914117044875
# Model for Station 6 has Accuracy: 0.6351318657229198
# Model for Station 7 has Accuracy: 0.5521655922902516
# Model for Station 8 has Accuracy: 0.47839134835435815
# Model for Station 9 has Accuracy: 0.44146037006351835
# Model for Station 10 has Accuracy: 0.531311374582019
# Model for Station 11 has Accuracy: 0.7155934534342985
# Model for Station 12 has Accuracy: 0.5779019585714147
# Model for Station 13 has Accuracy: 0.6534698715016426
# Model for Station 14 has Accuracy: 0.49540274553462477
# Model for Station 15 has Accuracy: 0.59947924236383
# Model for Station 16 has Accuracy: 0.3618306574584058
# Model for Station 17 has Accuracy: 0.5622496612380808
# Model for Station 18 has Accuracy: 0.4591212071347006
# Model for Station 19 has Accuracy: 0.5670711319635442
# Model for Station 21 has Accuracy: 0.4915611630485449
# Model for Station 22 has Accuracy: 0.42585311724801683
# Model for Station 23 has Accuracy: 0.4273700144835072
# Model for Station 24 has Accuracy: 0.40548979163480536
# Model for Station 25 has Accuracy: 0.7091853423827492
# Model for Station 26 has Accuracy: 0.48548934649573416
# Model for Station 27 has Accuracy: 0.5754220168041505
# Model for Station 28 has Accuracy: 0.38886297221803945
# Model for Station 29 has Accuracy: 0.5168873419468571
# Model for Station 30 has Accuracy: 0.3804840598743766
# Model for Station 31 has Accuracy: 0.3515014272855274
# Model for Station 32 has Accuracy: 0.44037724906847603
# Model for Station 33 has Accuracy: 0.4868361421205555
# Model for Station 34 has Accuracy: 0.4133403774267667
# Model for Station 35 has Accuracy: 0.4965092788181595
# Model for Station 36 has Accuracy: 0.5686660784112928
# Model for Station 37 has Accuracy: 0.5197147734375658
# Model for Station 38 has Accuracy: 0.3430161316776627
# Model for Station 39 has Accuracy: 0.4161292559897847
# Model for Station 40 has Accuracy: 0.4743929298271553
# Model for Station 41 has Accuracy: 0.5860585929856579
# Model for Station 42 has Accuracy: 0.582345580244425
# Model for Station 43 has Accuracy: 0.4291565337224384
# Model for Station 44 has Accuracy: 0.54554252974533
# Model for Station 45 has Accuracy: 0.5172995318006776
# Model for Station 46 has Accuracy: 0.3881549978641571
# Model for Station 47 has Accuracy: 0.7576802416193378
# Model for Station 48 has Accuracy: 0.44798298390909863
# Model for Station 49 has Accuracy: 0.5187893189964052
# Model for Station 51 has Accuracy: 0.5744240434526338
# Model for Station 52 has Accuracy: 0.40897338110556214
# Model for Station 53 has Accuracy: 0.7143058483970077
# Model for Station 54 has Accuracy: 0.482135532952948
# Model for Station 55 has Accuracy: 0.671111111111111
# Model for Station 56 has Accuracy: 0.49552941755248237
# Model for Station 57 has Accuracy: 0.6196446260525013
# Model for Station 58 has Accuracy: 0.5547762735439296
# Model for Station 59 has Accuracy: 0.44961024916388387
# Model for Station 60 has Accuracy: 0.48658099338173877
# Model for Station 61 has Accuracy: 0.46274827427690157
# Model for Station 62 has Accuracy: 0.6539198182075024
# Model for Station 63 has Accuracy: 0.5370993337824688
# Model for Station 64 has Accuracy: 0.636884848843197
# Model for Station 65 has Accuracy: 0.7854678425803802
# Model for Station 66 has Accuracy: 0.6157916857744641
# Model for Station 67 has Accuracy: 0.35965026592622923
# Model for Station 68 has Accuracy: 0.5078217634537694
# Model for Station 69 has Accuracy: 0.5691190270509666
# Model for Station 70 has Accuracy: 0.38653363836637855
# Model for Station 71 has Accuracy: 0.5658284364558129
# Model for Station 72 has Accuracy: 0.46766790385295154
# Model for Station 73 has Accuracy: 0.4590039164816571
# Model for Station 74 has Accuracy: 0.4732584860099175
# Model for Station 75 has Accuracy: 0.4306163014112805
# Model for Station 76 has Accuracy: 0.45037435676330906
# Model for Station 77 has Accuracy: 0.5682341397450485
# Model for Station 78 has Accuracy: 0.4496060765734347
# Model for Station 79 has Accuracy: 0.3922472356133596
# Model for Station 80 has Accuracy: 0.4036006721089529
# Model for Station 81 has Accuracy: 0.45065083994421445
# Model for Station 82 has Accuracy: 0.6333375983622289
# Model for Station 83 has Accuracy: 0.5269278702660625
# Model for Station 84 has Accuracy: 0.5381720318418179
# Model for Station 85 has Accuracy: 0.4940880103858323
# Model for Station 86 has Accuracy: 0.5368586200748796
# Model for Station 87 has Accuracy: 0.5689391468980354
# Model for Station 88 has Accuracy: 0.6093077609371192
# Model for Station 89 has Accuracy: 0.606072812911415
# Model for Station 90 has Accuracy: 1.0
# Model for Station 91 has Accuracy: 0.3251282919852809
# Model for Station 92 has Accuracy: 0.5113908802690246
# Model for Station 93 has Accuracy: 0.6838109444988947
# Model for Station 94 has Accuracy: 0.4754871328750781
# Model for Station 95 has Accuracy: 0.5874647935719073
# Model for Station 96 has Accuracy: 0.5658186361007059
# Model for Station 97 has Accuracy: 0.6013068536246496
# Model for Station 98 has Accuracy: 0.3933705241307732
# Model for Station 99 has Accuracy: 0.630813953488372
# Model for Station 100 has Accuracy: 0.36187363214916723
# Model for Station 101 has Accuracy: 0.6460519529536723
# Model for Station 102 has Accuracy: 0.4212017943338752

# %%
# create a model for each station. This time use all data, no training and test splits
for number in new_df.Number.unique():
    # get sub df and split into descriptve and target features
    sub_df = new_df[new_df.Number==number]
    X = sub_df[["tempClass", "WindSpeed", "Clouds", "workday", "rushHour", "daylight", "lunchHour", "daytime_darkEvening", "daytime_evening", "daytime_morning", "daytime_night"]]
    y = sub_df["bikeStandsPerc"]
    
    # create model
    rfc = RandomForestClassifier(n_estimators=100, max_features='auto', oob_score=True, random_state=1)
    rfc.fit(X, y)
    
    # save the model to disk
    filename = 'models/model_station_{}.sav'.format(number)
    pickle.dump(rfc, open(filename, 'wb'))
